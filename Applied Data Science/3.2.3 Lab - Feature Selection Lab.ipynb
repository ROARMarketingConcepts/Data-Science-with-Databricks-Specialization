# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# # Feature Selection Lab
#
# **Objective**: *Apply feature selection to a dataset to derive more meaningful features and improve predictions.*
#
# In this lab, you will apply what you've learned in this lesson. When complete, please use the answers to the exercises to answer questions in the following quiz within Coursera.

# %%
# %run "../../Includes/Classroom-Setup"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Mounting course-specific datasets to <b>/mnt/training</b>...</br>Datasets are already mounted to <b>/mnt/training</b> from <b>s3a://databricks-corp-training/common</b>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: DataFrame[]</div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res1: Boolean = false
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res2: Boolean = false
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res3: Boolean = false
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ## Exercise 1
#
# In this exercise, you will create a user-level table with the following columns:
#
# 1. `avg_resting_heartrate` – the average resting heartrate
# 1. `avg_active_heartrate` - the average active heartrate
# 1. `avg_bmi` – the average BMI
# 1. `avg_vo2` - the average oxygen volume
# 1. `avg_workout_minutes` - the average of total workout minutes
# 1. `avg_steps` - the average of total steps
# 1. `lifestyle` - the lifestyle that best describes the observation
#
# Run the cell below to create the table.

# %%
# %sql
CREATE OR REPLACE TABLE adsda.ht_user_metrics_pca
USING DELTA LOCATION "/adsda/ht-user-metrics-pca" AS (
  SELECT min(resting_heartrate) AS min_resting_heartrate,
         avg(resting_heartrate) AS avg_resting_heartrate,
         max(resting_heartrate) AS max_resting_heartrate,
         min(active_heartrate) AS min_active_heartrate,
         avg(active_heartrate) AS avg_active_heartrate,
         max(active_heartrate) AS max_active_heartrate,
         avg(bmi) AS avg_bmi,
         min(vo2) AS min_vo2,
         avg(vo2) AS avg_vo2,
         max(vo2) AS max_vo2,
         min(workout_minutes) AS min_workout_minutes,
         avg(workout_minutes) AS avg_workout_minutes,
         max(workout_minutes) AS max_workout_minutes,
         min(steps) AS min_steps,
         avg(steps) AS avg_steps,
         max(steps) AS max_steps,
         avg(steps) * avg(active_heartrate) AS as_x_aah,
         first(lifestyle) AS lifestyle
  FROM adsda.ht_daily_metrics
  GROUP BY device_id
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Run the cell below to convert to a Pandas DataFrame and introduce missing values.

# %%
import numpy as np
import pandas as pd
np.random.seed(0)
df = spark.table("adsda.ht_user_metrics_pca").toPandas()
df.loc[df.sample(frac=0.18).index, 'min_active_heartrate'] = np.nan
df.loc[df.sample(frac=0.05).index, 'min_steps'] = np.nan
df.shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: (3000, 18)</div>

# %% [markdown]
# ## Exercise 2
#
# In this exercise, you'll one-hot encode the `lifestyle` column.
#
# Fill in the blanks below to complete the task.

# %%
# TODO
df = pd.get_dummies(df, prefix='dummy', columns=['lifestyle'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Run this cell to ensure that all columns are numeric.

# %%
df = df.apply(pd.to_numeric)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Exercise 3
#
# In this exercise, you'll split the data into a training set and an inference set.
#
# Fill in the blanks below to complete the task.

# %%
# TODO
from sklearn.model_selection import train_test_split

train_df, inference_df = train_test_split(df, train_size=0.85, test_size=0.15, random_state=42)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# -sandbox
# **Coursera Quiz:** How many rows have missing values in the `min_steps` column in the training set?
#
# Write your code in the empty cell below to answer the question.
#
# **Hint:** Refer back to the previous lesson for guidance on how to complete this task.

# %%
# TODO
train_df['min_steps'].isna().sum()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: 127</div>

# %% [markdown]
# -sandbox
# ## Exercise 4
#
# In this exercise, you will fill in these missing values. Using the identified columns from the previous exercise, fill in the missing values with the mean of their respective column.
#
# Fill in the blanks below to complete the task.
#
# **Hint:** Recall that we want to find the mean of training set and use that to impute values on the training set *and* the test set.

# %%
# TODO
avg_bmi_mean = train_df['min_active_heartrate'].mean()
min_steps_mean = train_df['min_steps'].mean()

train_df['min_active_heartrate'] = train_df['min_active_heartrate'].fillna(avg_bmi_mean)
train_df['min_steps'] = train_df['min_steps'].fillna(min_steps_mean)

inference_df['min_active_heartrate'] = inference_df['min_active_heartrate'].fillna(avg_bmi_mean)
inference_df['min_steps'] = inference_df['min_steps'].fillna(min_steps_mean)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;command-640142902215327&gt;:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[&#39;min_active_heartrate&#39;] = train_df[&#39;min_active_heartrate&#39;].fillna(avg_bmi_mean)
# &lt;command-640142902215327&gt;:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[&#39;min_steps&#39;] = train_df[&#39;min_steps&#39;].fillna(min_steps_mean)
# &lt;command-640142902215327&gt;:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inference_df[&#39;min_active_heartrate&#39;] = inference_df[&#39;min_active_heartrate&#39;].fillna(avg_bmi_mean)
# &lt;command-640142902215327&gt;:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inference_df[&#39;min_steps&#39;] = inference_df[&#39;min_steps&#39;].fillna(min_steps_mean)
# </div>

# %% [markdown]
# **Coursera Quiz:** What is the mean of the `min_steps_mean` feature rounded to the nearest hundredth place?

# %%
# TODO
train_df['min_steps'].mean()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: 9090.116384647132</div>

# %% [markdown]
# ## Exercise 5
#
# Create the `X_train`, `X_test`, `y_train`, `y_test` from the train_df. Recall that we are trying to predict the `avg_bmi`.
#
# Fill in the blanks below to complete the task.

# %%
# TODO
from sklearn.model_selection import train_test_split

X = train_df.drop('avg_bmi', axis=1)
y = train_df['avg_bmi']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.1, random_state=42)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# **Coursera Quiz**: How many rows are in the training set?

# %%
X_train.shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[17]: (2295, 20)</div>

# %% [markdown]
# ## Exercise 6
#
# In this exercise, you will fit a LASSO model. Fill in the blanks to fit a model with a `0.01` alpha, then run the cells to check coefficients.
#
# Fill in the blanks below to complete the task.

# %%
# TODO
from sklearn.linear_model import Lasso

lr = Lasso(alpha=.01)
lr.fit(X_train, y_train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2660.628531831539, tolerance: 4.789288946633347
#   model = cd_fast.enet_coordinate_descent(
# Out[19]: Lasso(alpha=0.01)</div>

# %% [markdown]
# Print out the R^2 score

# %%
print(lr.score(X_test, y_test))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">0.8998620777876551
# </div>

# %% [markdown]
# **Coursera Quiz**: Which feature had the largest coefficient?

# %%
pd.DataFrame(list(zip(lr.coef_, X.columns)), columns=['coef', 'feature_name']).sort_values('coef', ascending=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>coef</th>
#       <th>feature_name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>16</th>
#       <td>4.616560</td>
#       <td>dummy_Athlete</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.078099</td>
#       <td>max_resting_heartrate</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>0.018453</td>
#       <td>min_workout_minutes</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.013055</td>
#       <td>max_active_heartrate</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>0.001642</td>
#       <td>max_steps</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.000006</td>
#       <td>min_active_heartrate</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>0.000002</td>
#       <td>as_x_aah</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>0.000000</td>
#       <td>dummy_Weight Trainer</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>-0.000000</td>
#       <td>dummy_Cardio Enthusiast</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>-0.000000</td>
#       <td>max_vo2</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>-0.000035</td>
#       <td>min_steps</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>-0.001597</td>
#       <td>avg_steps</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>-0.004664</td>
#       <td>max_workout_minutes</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>-0.011216</td>
#       <td>avg_active_heartrate</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>-0.021188</td>
#       <td>min_resting_heartrate</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>-0.061239</td>
#       <td>min_vo2</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>-0.078660</td>
#       <td>avg_vo2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-0.275459</td>
#       <td>avg_resting_heartrate</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>-0.467421</td>
#       <td>avg_workout_minutes</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>-14.534136</td>
#       <td>dummy_Sedentary</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Exercise 7
#
# In this exercise, you will take the feature with the highest coefficients and refit a model.
#
# Fill in the blanks below to complete the task.

# %%
# TODO
X = train_df[[_____]]
y = train_df[_____]

______, ______, ______, ______ = ______(X, y, test_size=.1, random_state=42)
lr = ______(alpha=.01)
lr.______(______, ______)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Compute the the R-squared score.
#
# Fill in the blanks below to complete the task.

# %%
# TODO
lr._____(X_test, y_test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Congrats! That concludes our lesson on feature selection!
#
# Be sure to submit your quiz answers to Coursera, and join us in the next lesson to learn about tree based models!

# %% [markdown]
# -sandbox
# &copy; 2021 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
