# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# # Label Imbalance Lab
#
# **Objective**: *Apply label balancing techniques to a random forest to optimize a recall metric.*
#
# In this lab you will complete a series of guided exercises where you build a random forest to solve an imbalanced binary classification problem and apply both bootstrapping and record weighting to balance the data set. They should then compare the results to an unbalanced baseline that was given. When complete, please use your answers to the exercises to answer questions in the following quiz within Coursera.

# %%
# %pip install imbalanced-learn
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# Requirement already satisfied: imbalanced-learn in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d8a8122d-13c2-409c-92d4-9fb7c93776a1/lib/python3.8/site-packages (0.8.0)
# Requirement already satisfied: scikit-learn&gt;=0.24 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-d8a8122d-13c2-409c-92d4-9fb7c93776a1/lib/python3.8/site-packages (from imbalanced-learn) (0.24.2)
# Requirement already satisfied: numpy&gt;=1.13.3 in /databricks/python3/lib/python3.8/site-packages (from imbalanced-learn) (1.19.2)
# Requirement already satisfied: scipy&gt;=0.19.1 in /databricks/python3/lib/python3.8/site-packages (from imbalanced-learn) (1.5.2)
# Requirement already satisfied: joblib&gt;=0.11 in /databricks/python3/lib/python3.8/site-packages (from imbalanced-learn) (0.17.0)
# Requirement already satisfied: threadpoolctl&gt;=2.0.0 in /databricks/python3/lib/python3.8/site-packages (from scikit-learn&gt;=0.24-&gt;imbalanced-learn) (2.1.0)
# WARNING: You are using pip version 20.2.4; however, version 21.1.3 is available.
# You should consider upgrading via the &#39;/local_disk0/.ephemeral_nfs/envs/pythonEnv-d8a8122d-13c2-409c-92d4-9fb7c93776a1/bin/python -m pip install --upgrade pip&#39; command.
# Python interpreter will be restarted.
# </div>

# %%
# %run ../../Includes/Classroom-Setup
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Mounting course-specific datasets to <b>/mnt/training</b>...</br>Datasets are already mounted to <b>/mnt/training</b> from <b>s3a://databricks-corp-training/common</b>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: DataFrame[]</div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res1: Boolean = false
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res2: Boolean = false
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res3: Boolean = false
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ## Exercise 1
#
# In this exercise, you will use the user-level lifestyle table. Run the following cell to make sure you can access the `adsda.ht_user_metrics_lifestyle` table.

# %%
# %sql
SELECT *
FROM adsda.ht_user_metrics_lifestyle
LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>avg_resting_heartrate</th><th>avg_active_heartrate</th><th>bmi</th><th>avg_vo2</th><th>avg_workout_minutes</th><th>steps</th><th>lifestyle</th></tr></thead><tbody><tr><td>82.68379727873081</td><td>139.43487473206162</td><td>22.398063650890794</td><td>20.99401157735923</td><td>5.5026324666656405</td><td>5171.495890410959</td><td>Sedentary</td></tr><tr><td>77.73294228506452</td><td>127.05715346661702</td><td>25.150812654086298</td><td>25.52747526955064</td><td>37.2167018100805</td><td>7115.591780821917</td><td>Weight Trainer</td></tr><tr><td>86.51162895591307</td><td>147.31573126952208</td><td>19.148256000462478</td><td>19.448406520026342</td><td>45.00008651086257</td><td>7257.693150684931</td><td>Weight Trainer</td></tr><tr><td>77.55054135762612</td><td>129.5770039396946</td><td>24.240375728856797</td><td>21.40130178285617</td><td>37.886068725488464</td><td>7129.690410958904</td><td>Weight Trainer</td></tr><tr><td>68.93310580458204</td><td>136.50268661405897</td><td>30.726595797380472</td><td>28.855230169253637</td><td>32.24198398599063</td><td>6958.378082191781</td><td>Weight Trainer</td></tr><tr><td>69.31244794850774</td><td>167.18585016710105</td><td>27.1326690342849</td><td>30.939205114246853</td><td>5.119426899323105</td><td>5128.024657534246</td><td>Sedentary</td></tr><tr><td>64.64397544858174</td><td>152.9654977304546</td><td>29.17716498363452</td><td>28.92795344089978</td><td>5.015081852287961</td><td>5167.789041095891</td><td>Sedentary</td></tr><tr><td>81.33282756113321</td><td>137.57131998347788</td><td>20.850071485672633</td><td>22.564006304582495</td><td>42.375521457262316</td><td>7281.586301369863</td><td>Weight Trainer</td></tr><tr><td>64.79507042723496</td><td>139.39836367080545</td><td>31.386431213715433</td><td>29.096510773429188</td><td>33.3298371336183</td><td>7029.608219178082</td><td>Weight Trainer</td></tr><tr><td>89.51117796589962</td><td>126.57048164605168</td><td>19.830753716401606</td><td>19.750462151303648</td><td>43.30528046136424</td><td>7362.769863013698</td><td>Weight Trainer</td></tr></tbody></table></div>

# %% [markdown]
# Fill in the following cell to create a Pandas DataFrame from the Spark table.

# %%
# TODO
ht_metrics_pd_df = spark.table("adsda.ht_user_metrics_lifestyle").toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Exercise 2
#
# In this exercise, encode the `lifestyle` column by passing a dictionary of all values to the `lifestyle`.
#
# Use the following values:  `Sedentary` should be a 0 and all other classes should be 1.
#
# Fill in the blanks in the below code block.

# %%
# TODO
ht_metrics_pd_df['lifestyle_cat'] = ht_metrics_pd_df['lifestyle'].map({'Sedentary':0, 'Weight Trainer':1, 'Athlete':1, 'Cardio Enthusiast':1 })
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Exercise 3
#
# In this exercise, you will build a random forest classification model.
#
# We will once again try to predict a user's `lifestyle` using their other metrics.

# %% [markdown]
# Before splitting the data and fitting the model, import the packages you will need from sklearn for the train test split and the random forest classifier.

# %%
# TODO
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ht_metrics_pd_df.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>avg_resting_heartrate</th>
#       <th>avg_active_heartrate</th>
#       <th>bmi</th>
#       <th>avg_vo2</th>
#       <th>avg_workout_minutes</th>
#       <th>steps</th>
#       <th>lifestyle</th>
#       <th>lifestyle_cat</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>82.683797</td>
#       <td>139.434875</td>
#       <td>22.398064</td>
#       <td>20.994012</td>
#       <td>5.502632</td>
#       <td>5171.495890</td>
#       <td>Sedentary</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>77.732942</td>
#       <td>127.057153</td>
#       <td>25.150813</td>
#       <td>25.527475</td>
#       <td>37.216702</td>
#       <td>7115.591781</td>
#       <td>Weight Trainer</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>86.511629</td>
#       <td>147.315731</td>
#       <td>19.148256</td>
#       <td>19.448407</td>
#       <td>45.000087</td>
#       <td>7257.693151</td>
#       <td>Weight Trainer</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>77.550541</td>
#       <td>129.577004</td>
#       <td>24.240376</td>
#       <td>21.401302</td>
#       <td>37.886069</td>
#       <td>7129.690411</td>
#       <td>Weight Trainer</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>68.933106</td>
#       <td>136.502687</td>
#       <td>30.726596</td>
#       <td>28.855230</td>
#       <td>32.241984</td>
#       <td>6958.378082</td>
#       <td>Weight Trainer</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# TODO
X = ht_metrics_pd_df.drop(['lifestyle','lifestyle_cat'],axis=1)
y = ht_metrics_pd_df['lifestyle_cat']

X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=42)

rf = RandomForestClassifier(random_state=42)
rf.fit(X_train, y_train)

y_train_predicted = rf.predict(X_train)
y_test_predicted = rf.predict(X_test)

print("Accuracy on training set: ", round(rf.score(X_train, y_train),3))
print("Accuracy on test set: ", round(rf.score(X_test, y_test), 3))
print(confusion_matrix(y_test, rf.predict(X_test)))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Accuracy on training set:  1.0
# Accuracy on test set:  1.0
# [[ 79   0]
#  [  0 671]]
# </div>

# %% [markdown]
# **Coursera Quiz:** For the base `rf` model, what is the accuracy score on the training and test set?

# %% [markdown]
# ## Exercise 4
#
# Change the `class_weight` parameter to `balanced`, and compute the accuracy and print the confusion matrix on the test set.

# %%
# TODO
from sklearn.metrics import confusion_matrix

rf = RandomForestClassifier(class_weight="balanced")
rf.fit(X_train, y_train)

print(rf.score(X_test, y_test))
print(confusion_matrix(y_test, rf.predict(X_test)))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">1.0
# [[ 79   0]
#  [  0 671]]
# </div>

# %% [markdown]
# **Coursera Quiz:** For the class weight balanced model, what is the accuracy score on the test set?

# %% [markdown]
# **Coursera Quiz:** For the class weight balanced model, what is the total delta of True Negatives from the base Random Forest model?

# %% [markdown]
# ## Exercise 5
#
# Choose a `sampling strategy` of `minority`. Then fit and score a random forest model.

# %%
# TODO
from imblearn.over_sampling import RandomOverSampler

oversample = RandomOverSampler(sampling_strategy='minority')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Create an oversample of the features and target.

# %%
# TODO
X_over, y_over = oversample.fit_resample(X, y)

print(y_over.value_counts())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">1    2688
# 0    2688
# Name: lifestyle_cat, dtype: int64
# </div>

# %% [markdown]
# Create a train test split with the resampled data

# %%
# TODO
X_train, X_test, y_train, y_test = train_test_split(X_over,y_over)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# **Coursera Quiz:** How many of our `sedentary` class do we now have in our train set?

# %%
# TODO 
y_train.value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: 1    2018
# 0    2014
# Name: lifestyle_cat, dtype: int64</div>

# %% [markdown]
# Fit a model with the new train test split and print the confusion matrix

# %%
# TODO
rf = RandomForestClassifier(random_state=42)

rf.fit(X_train, y_train)
print(rf.score(X_test, y_test))
print(confusion_matrix(y_test, rf.predict(X_test)))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">1.0
# [[644   0]
#  [  0 700]]
# </div>

# %% [markdown]
# **Coursera Quiz:** For the class weight balanced model, what is the accuracy score on the test set?

# %% [markdown]
# **Coursera Quiz:** For the class weight balanced model, what is the total delta of True Negatives from the base Random Forest model?

# %% [markdown]
# -sandbox
# &copy; 2021 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
