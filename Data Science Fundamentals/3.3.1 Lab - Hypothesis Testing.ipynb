# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# -sandbox
# # Hypothesis Testing (25 mins)
#
# **Objective**: *Perform a two-sample, two-sided t-test to compare sample means.*
#
# In this lab, you will complete a series of exercises to perform a t-test.
#
# We want to determine whether the population mean of daily steps taken for the athlete health tracker users is equal to the population mean of daily steps taken for the cardio enthusiast health tracker users.
#
# The null and alternative hypotheses for this test are:
#
# * H<sub>0</sub> = the mean of daily steps taken for athlete users is equal to the mean of daily steps taken for cardio enthusiast users.
# * H<sub>1</sub> = the mean of daily steps taken for athlete users is not equal to the mean of daily steps taken for cardio enthusiast users.

# %%
# %run "../../Includes/Classroom-Setup"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Mounting course-specific datasets to <b>/mnt/training</b>...</br>Datasets are already mounted to <b>/mnt/training</b> from <b>s3a://databricks-corp-training/common</b>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: DataFrame[]</div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res1: Boolean = false
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res2: Boolean = false
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Exercise 1
#
# Compute the sample mean of daily steps taken for sedentary users and cardio enthusiast users.

# %%
# %sql
SELECT DISTINCT (lifestyle)
FROM ht_daily_metrics
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>lifestyle</th></tr></thead><tbody><tr><td>Cardio Enthusiast</td></tr><tr><td>Athlete</td></tr><tr><td>Weight Trainer</td></tr><tr><td>Sedentary</td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE ht_daily_metrics
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>device_id</td><td>string</td><td></td></tr><tr><td>dte</td><td>string</td><td></td></tr><tr><td>resting_heartrate</td><td>double</td><td></td></tr><tr><td>active_heartrate</td><td>double</td><td></td></tr><tr><td>bmi</td><td>double</td><td></td></tr><tr><td>vo2</td><td>double</td><td></td></tr><tr><td>workout_minutes</td><td>double</td><td></td></tr><tr><td>lifestyle</td><td>string</td><td></td></tr><tr><td>steps</td><td>int</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Partitioning</td><td></td><td></td></tr><tr><td>Not partitioned</td><td></td><td></td></tr></tbody></table></div>

# %%
# %sql
SELECT lifestyle, round(mean(steps),0) AS mean_steps
FROM ht_daily_metrics
WHERE lifestyle IN ("Sedentary","Cardio Enthusiast")
GROUP BY lifestyle;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>lifestyle</th><th>mean_steps</th></tr></thead><tbody><tr><td>Cardio Enthusiast</td><td>13235.0</td></tr><tr><td>Sedentary</td><td>5169.0</td></tr></tbody></table></div>

# %% [markdown]
# ## Exercise 2
# Compute the sample variance of daily steps taken for sedentary users and cardio enthusiast users.

# %%
# %sql
SELECT lifestyle, round(variance(steps),0) AS var_steps
FROM ht_daily_metrics
WHERE lifestyle IN ("Sedentary","Cardio Enthusiast")
GROUP BY lifestyle;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>lifestyle</th><th>var_steps</th></tr></thead><tbody><tr><td>Cardio Enthusiast</td><td>1.3171492E7</td></tr><tr><td>Sedentary</td><td>612624.0</td></tr></tbody></table></div>

# %% [markdown]
# ## Exercise 3
# Compute the sample size for sedentary users and cardio enthusiast users.

# %%
# %sql
SELECT lifestyle, count(*) AS count
FROM ht_daily_metrics
WHERE lifestyle IN ("Sedentary","Cardio Enthusiast")
GROUP BY lifestyle;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>lifestyle</th><th>count</th></tr></thead><tbody><tr><td>Cardio Enthusiast</td><td>388360</td></tr><tr><td>Sedentary</td><td>113880</td></tr></tbody></table></div>

# %% [markdown]
# ## Exercise 4
# Compute the T-statistic using the sample statistics.

# %%
# TODO
from math import sqrt

athlete_mean = <FILL IN>
athlete_variance = <FILL IN>
athlete_size = <FILL IN>

cardio_mean = <FILL IN>
cardio_variance = <FILL IN>
cardio_size = <FILL IN>

test_statistic = (athlete_mean - cardio_mean) / sqrt((athlete_variance / athlete_size) + (cardio_variance / cardio_size))
print(f"T-statistic = {test_statistic}")

# %% [markdown]
# ## Exercise 5
# Compute the degrees of freedom using the sample statistics.

# %%
# TODO
df_numerator = ((athlete_variance / athlete_size) + (cardio_variance / cardio_size))**2
df_denominator = (athlete_variance / athlete_size)**2 / (athlete_size - 1) + ((cardio_variance / cardio_size)**2 / (cardio_size - 1))
df = <FILL_IN>
print(f"Degrees-of-freedom = {df}")

# %% [markdown]
# ## Exercise 6
#
# Compute the p-value for this T-test by passing in the `test_statistic` and the `df` to `t.cdf()`.

# %%
# TODO
from scipy.stats import t
p_value = t.cdf(<FILL IN>)
print(f"p-value = {p_value}")

# %% [markdown]
# -sandbox
# ## Exercise 7
#
# Determine whether we should reject the null hypothesis.
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> Use a significance level of 0.05.

# %%
# TODO

# %% [markdown]
# ## Exercise 8
#
# Phew! That was a lot of work to answer a simple question.
#
# Luckily, Python's `scipy` module makes this process a bit easier than it already has.
#
# Check out the demonstration below showing how to perform this same test in a single step only using Python.

# %%
from scipy.stats import ttest_ind

athlete_daily_steps = spark.sql("SELECT steps FROM dsfda.ht_daily_metrics WHERE lifestyle = 'Athlete'").toPandas()["steps"]
cardio_daily_steps = spark.sql("SELECT steps FROM dsfda.ht_daily_metrics WHERE lifestyle = 'Cardio Enthusiast'").toPandas()["steps"]

ttest_ind(athlete_daily_steps, cardio_daily_steps, equal_var = False)

# %% [markdown]
# Notice that the *same test statistic* and *same p-value* were calculated with far less code!
#
# While it's good to understand how these `scipy` tools work, it's good practice and efficient to use them as much as possible.

# %% [markdown]
# -sandbox
# &copy; 2021 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
