# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# # Descriptive Statistics
#
# **Objective**: *Use descriptive statistics to gather information about a data set.*
#
# In this lab, you will complete a series of exercises to calculate various summary statistics of the `dsfda.ht_daily_metrics` data set.

# %%
# %run "../../Includes/Classroom-Setup"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Mounting course-specific datasets to <b>/mnt/training</b>...</br>Datasets are already mounted to <b>/mnt/training</b> from <b>s3a://databricks-corp-training/common</b>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: DataFrame[]</div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res4: Boolean = false
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res5: Boolean = false
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Part 1: Measures of Central Tendency

# %% [markdown]
# -sandbox
# #### Exercise 1: Mean
#
# Use the `AVG` SQL function to calculate the average resting heartrate, as an integer, for each lifestyle.
#
# **Hint:** If needed, check out the [Spark SQL documentation on `avg`](https://spark.apache.org/docs/3.0.1/api/sql/index.html#avg).

# %%
# %sql
SELECT *
FROM ht_daily_metrics
LIMIT 5;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>device_id</th><th>dte</th><th>resting_heartrate</th><th>active_heartrate</th><th>bmi</th><th>vo2</th><th>workout_minutes</th><th>lifestyle</th><th>steps</th></tr></thead><tbody><tr><td>01c99836-e48b-11ea-8204-0242ac110002</td><td>2019-01-01</td><td>84.21990807741808</td><td>122.36614513322988</td><td>24.001442078098176</td><td>23.520174244131812</td><td>55.290771176379415</td><td>Athlete</td><td>10345</td></tr><tr><td>01c99836-e48b-11ea-8204-0242ac110002</td><td>2019-01-02</td><td>75.56009664616255</td><td>132.08213570805194</td><td>23.981473224271443</td><td>23.241395323502907</td><td>27.99672176043603</td><td>Athlete</td><td>9140</td></tr><tr><td>01c99836-e48b-11ea-8204-0242ac110002</td><td>2019-01-03</td><td>67.95214658754116</td><td>133.897419834453</td><td>24.01203323166733</td><td>23.844758959223647</td><td>6.403982740621206</td><td>Athlete</td><td>8895</td></tr><tr><td>01c99836-e48b-11ea-8204-0242ac110002</td><td>2019-01-04</td><td>72.07402249362427</td><td>130.27996931348147</td><td>24.184537499965806</td><td>23.65815389509837</td><td>21.06190942499232</td><td>Athlete</td><td>10683</td></tr><tr><td>01c99836-e48b-11ea-8204-0242ac110002</td><td>2019-01-05</td><td>84.21089219223238</td><td>130.45737338095134</td><td>24.504363282462865</td><td>23.930176012952693</td><td>11.171669668342071</td><td>Athlete</td><td>8752</td></tr></tbody></table></div>

# %%
# %sql
SELECT lifestyle, round(avg(resting_heartrate),1) AS average
FROM ht_daily_metrics
GROUP BY lifestyle;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>lifestyle</th><th>average</th></tr></thead><tbody><tr><td>Cardio Enthusiast</td><td>53.0</td></tr><tr><td>Athlete</td><td>57.8</td></tr><tr><td>Weight Trainer</td><td>73.3</td></tr><tr><td>Sedentary</td><td>79.1</td></tr></tbody></table></div>

# %% [markdown]
# -sandbox
# #### Exercise 2: Median
#
# Use the `percentile` SQL function to calculate the median resting heartrate, as an integer, for the "Athlete" lifestyle.
#
# Note that this code block takes longer to run; this is because calculating the median requires shuffling across worker nodes.
#
# **Hint:** If needed, check out the [Spark SQL documentation on `percentile`](https://spark.apache.org/docs/3.0.1/api/sql/index.html#percentile).

# %%
# %sql
SELECT lifestyle, round(percentile(resting_heartrate,0.5),0) AS median
FROM ht_daily_metrics
WHERE lifestyle='Athlete'
GROUP BY lifestyle;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>lifestyle</th><th>median</th></tr></thead><tbody><tr><td>Athlete</td><td>57.0</td></tr></tbody></table></div>

# %% [markdown]
# -sandbox
# #### Exercise 3: Mode
#
# Calculate the mode, as an integer, of the resting heartrate for each lifestyle.
#
# **Hint:** Cast the heartrate to the nearest integer first. You can use the Spark SQL documentation on `cast` for reference.
#
# **Hint:** Try to find the `mode` Spark SQL function in the documentation on your own.

# %%
# %sql
SELECT round(resting_heartrate,0) AS mode
FROM ht_daily_metrics
GROUP BY round(resting_heartrate,0)
ORDER BY count(*) DESC
LIMIT 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>mode</th></tr></thead><tbody><tr><td>56.0</td></tr></tbody></table></div>

# %% [markdown]
# ## Part 2: Measures of Dispersion

# %% [markdown]
# -sandbox
# #### Exercise 4: Standard Deviation
#
# Calculate the standard deviation of the resting heartrate for each lifestyle.
#
# **Hint:** Cast the heartrate to the nearest integer first.
#
# **Hint:** Use the Spark SQL documentation to determine which function computes the standard deviation.

# %%
# %sql
SELECT lifestyle, round(stddev(round(resting_heartrate,0)),2) AS std_dev
FROM ht_daily_metrics
GROUP BY lifestyle
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>lifestyle</th><th>std_dev</th></tr></thead><tbody><tr><td>Cardio Enthusiast</td><td>8.07</td></tr><tr><td>Athlete</td><td>9.88</td></tr><tr><td>Weight Trainer</td><td>13.07</td></tr><tr><td>Sedentary</td><td>11.88</td></tr></tbody></table></div>

# %% [markdown]
# -sandbox
# #### Exercise 5: Interquartile Range
#
# Calculate the interquartile range of resting heartrate, as an integer, for each lifestyle.
#
# **Hint:** Recall that the interquartile range is the difference between the 75th percentile and the 25th percentile.
#
# **Hint:** Refer to previous exercises in this lab to determine which Spark SQL function can be used to compute the value at a given percentile.

# %%
# %sql
SELECT lifestyle, round(percentile(resting_heartrate,0.75) - percentile(resting_heartrate,0.25),1) AS intquart_range
FROM ht_daily_metrics
GROUP BY lifestyle;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>lifestyle</th><th>intquart_range</th></tr></thead><tbody><tr><td>Cardio Enthusiast</td><td>10.8</td></tr><tr><td>Athlete</td><td>12.8</td></tr><tr><td>Weight Trainer</td><td>19.2</td></tr><tr><td>Sedentary</td><td>16.1</td></tr></tbody></table></div>

# %% [markdown]
# Congratulations! You've completed the Descriptive Statistics Lab.
#
# If you have any trouble with any of this course's labs, be sure to check out the solutions to the labs in the Solutions folder.

# %% [markdown]
# -sandbox
# &copy; 2021 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
